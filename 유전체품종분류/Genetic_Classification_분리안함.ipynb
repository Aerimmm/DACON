# %% [markdown]
# # Genetic Classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import random
import os

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(0) # Seed 고정

# %%
train = pd.read_csv('./train_test_data/train.csv')
test = pd.read_csv('./train_test_data/test.csv')

# %%
train
# Out:
#             id  father  mother  gender  trait SNP_01 SNP_02 SNP_03 SNP_04  \
# 0    TRAIN_000       0       0       0      2    G G    A G    A A    G A
# 1    TRAIN_001       0       0       0      2    A G    A G    C A    A A
# 2    TRAIN_002       0       0       0      2    G G    G G    A A    G A
# 3    TRAIN_003       0       0       0      1    A A    G G    A A    G A
# 4    TRAIN_004       0       0       0      2    G G    G G    C C    A A
# ..         ...     ...     ...     ...    ...    ...    ...    ...    ...
# 257  TRAIN_257       0       0       0      2    A G    A G    A A    G A
# 258  TRAIN_258       0       0       0      2    G G    A A    C A    A A
# 259  TRAIN_259       0       0       0      1    A G    G G    A A    G A
# 260  TRAIN_260       0       0       0      1    A A    G G    A A    G A
# 261  TRAIN_261       0       0       0      2    G G    A G    C A    G G
#
#     SNP_05  ... SNP_07 SNP_08 SNP_09 SNP_10 SNP_11 SNP_12 SNP_13 SNP_14  \
# 0      C A  ...    A A    G G    A A    G G    A G    A A    A A    A A
# 1      A A  ...    A A    G A    A A    A G    A A    G A    G G    A A
# 2      C C  ...    A A    G A    G A    A G    A A    A A    A A    A A
# 3      A A  ...    G G    A A    G G    A G    G G    G G    G G    A A
# 4      C C  ...    A A    A A    A A    G G    A A    A A    A G    A A
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 257    C C  ...    A A    G A    A A    G G    A G    G A    A A    A A
# 258    A A  ...    G A    G A    A A    A G    A G    A A    A G    A A
# 259    A A  ...    G G    G A    G A    A A    G G    G G    G G    C A
# 260    A A  ...    G G    A A    G A    A G    A G    G A    G G    C A
# 261    C C  ...    A A    A A    A A    G G    A A    A A    G G    A A
#
#     SNP_15 class
# 0      A A     B
# 1      A A     C
# 2      A A     B
# 3      G G     A
# 4      G A     C
# ..     ...   ...
# 257    A A     B
# 258    G A     C
# 259    G G     A
# 260    G G     A
# 261    G A     B
#
# [262 rows x 21 columns]

# %%
test
# Out:
#            id  father  mother  gender  trait SNP_01 SNP_02 SNP_03 SNP_04  \
# 0    TEST_000       0       0       0      1    A G    G G    A A    G A
# 1    TEST_001       0       0       0      2    G G    A G    C C    G G
# 2    TEST_002       0       0       0      2    G G    A G    A A    A A
# 3    TEST_003       0       0       0      2    G G    A G    C A    A A
# 4    TEST_004       0       0       0      1    A A    G G    A A    G G
# ..        ...     ...     ...     ...    ...    ...    ...    ...    ...
# 170  TEST_170       0       0       0      2    A G    G G    C C    A A
# 171  TEST_171       0       0       0      2    G G    A A    A A    A A
# 172  TEST_172       0       0       0      2    G G    A A    A A    A A
# 173  TEST_173       0       0       0      2    A G    G G    C A    G A
# 174  TEST_174       0       0       0      2    G G    G G    C C    G A
#
#     SNP_05 SNP_06 SNP_07 SNP_08 SNP_09 SNP_10 SNP_11 SNP_12 SNP_13 SNP_14  \
# 0      A A    A G    G G    G A    G A    A G    A G    G A    G G    C A
# 1      C C    A A    A A    A A    A A    G G    A G    A A    A A    A A
# 2      C A    A G    A A    A A    A A    A G    A A    G A    G G    A A
# 3      C C    A A    A A    A A    A A    G G    A A    G A    A G    A A
# 4      A A    G G    G G    A A    G G    A G    G G    G A    G G    A A
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 170    C A    A G    A A    G G    A A    G G    G G    A A    A A    A A
# 171    C A    A G    A A    A A    A A    A G    A A    A A    A G    A A
# 172    C A    A G    A A    A A    A A    G G    A G    A A    A G    A A
# 173    C C    G G    A A    G A    A A    G G    A G    A A    A A    A A
# 174    C A    A A    G A    G G    A A    G G    G G    A A    A A    A A
#
#     SNP_15
# 0      G A
# 1      A A
# 2      G G
# 3      A A
# 4      G G
# ..     ...
# 170    G A
# 171    G A
# 172    G G
# 173    A A
# 174    A A
#
# [175 rows x 20 columns]

# %%
train.describe()
# Out:
#        father  mother  gender       trait
# count   262.0   262.0   262.0  262.000000
# mean      0.0     0.0     0.0    1.736641
# std       0.0     0.0     0.0    0.441298
# min       0.0     0.0     0.0    1.000000
# 25%       0.0     0.0     0.0    1.000000
# 50%       0.0     0.0     0.0    2.000000
# 75%       0.0     0.0     0.0    2.000000
# max       0.0     0.0     0.0    2.000000

# %%
train.describe(include = ['O'])
# Out:
#                id SNP_01 SNP_02 SNP_03 SNP_04 SNP_05 SNP_06 SNP_07 SNP_08  \
# count         262    262    262    262    262    262    262    262    262
# unique        262      3      3      3      3      3      3      3      3
# top     TRAIN_000    G G    G G    A A    A A    A A    A G    A A    G A
# freq            1    141    108    122    120     94    122    163     96
#
#        SNP_09 SNP_10 SNP_11 SNP_12 SNP_13 SNP_14 SNP_15 class
# count     262    262    262    262    262    262    262   262
# unique      3      3      3      3      3      3      3     3
# top       A A    G G    A G    A A    G G    A A    A A     B
# freq      182    151     96    136    115    185    107   114

# %%
train.columns
# Out:
# Index(['id', 'father', 'mother', 'gender', 'trait', 'SNP_01', 'SNP_02',
#        'SNP_03', 'SNP_04', 'SNP_05', 'SNP_06', 'SNP_07', 'SNP_08', 'SNP_09',
#        'SNP_10', 'SNP_11', 'SNP_12', 'SNP_13', 'SNP_14', 'SNP_15', 'class'],
#       dtype='object')

# %%
train['SNP_01'].unique()
# Out:
# array(['G G', 'A G', 'A A'], dtype=object)

# %%
train['SNP_02'].unique()
# Out:
# array(['A G', 'G G', 'A A'], dtype=object)

# %%
train['SNP_03'].unique()
# Out:
# array(['A A', 'C A', 'C C'], dtype=object)

# %%
train['SNP_04'].unique()
# Out:
# array(['G A', 'A A', 'G G'], dtype=object)

# %%
train['SNP_05'].unique()
# Out:
# array(['C A', 'A A', 'C C'], dtype=object)

# %%
idtest = test['id']
idtest
# Out:
# 0      TEST_000
# 1      TEST_001
# 2      TEST_002
# 3      TEST_003
# 4      TEST_004
#          ...
# 170    TEST_170
# 171    TEST_171
# 172    TEST_172
# 173    TEST_173
# 174    TEST_174
# Name: id, Length: 175, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
cols = ('SNP_01', 'SNP_02', 'SNP_03', 'SNP_04', 'SNP_05', 'SNP_06',
       'SNP_07', 'SNP_08', 'SNP_09', 'SNP_10', 'SNP_11', 'SNP_12', 'SNP_13',
       'SNP_14', 'SNP_15','class')

# %%
for c in cols:
    lb = LabelEncoder() 
    lb.fit(list(train[c].values)) 
    train[c] = lb.transform(list(train[c].values))

# %%
train
# Out:
#             id  father  mother  gender  trait  SNP_01  SNP_02  SNP_03  SNP_04  \
# 0    TRAIN_000       0       0       0      2       2       1       0       1
# 1    TRAIN_001       0       0       0      2       1       1       1       0
# 2    TRAIN_002       0       0       0      2       2       2       0       1
# 3    TRAIN_003       0       0       0      1       0       2       0       1
# 4    TRAIN_004       0       0       0      2       2       2       2       0
# ..         ...     ...     ...     ...    ...     ...     ...     ...     ...
# 257  TRAIN_257       0       0       0      2       1       1       0       1
# 258  TRAIN_258       0       0       0      2       2       0       1       0
# 259  TRAIN_259       0       0       0      1       1       2       0       1
# 260  TRAIN_260       0       0       0      1       0       2       0       1
# 261  TRAIN_261       0       0       0      2       2       1       1       2
#
#      SNP_05  ...  SNP_07  SNP_08  SNP_09  SNP_10  SNP_11  SNP_12  SNP_13  \
# 0         1  ...       0       2       0       2       1       0       0
# 1         0  ...       0       1       0       1       0       1       2
# 2         2  ...       0       1       1       1       0       0       0
# 3         0  ...       2       0       2       1       2       2       2
# 4         2  ...       0       0       0       2       0       0       1
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 257       2  ...       0       1       0       2       1       1       0
# 258       0  ...       1       1       0       1       1       0       1
# 259       0  ...       2       1       1       0       2       2       2
# 260       0  ...       2       0       1       1       1       1       2
# 261       2  ...       0       0       0       2       0       0       2
#
#      SNP_14  SNP_15  class
# 0         0       0      1
# 1         0       0      2
# 2         0       0      1
# 3         0       2      0
# 4         0       1      2
# ..      ...     ...    ...
# 257       0       0      1
# 258       0       1      2
# 259       1       2      0
# 260       1       2      0
# 261       0       1      1
#
# [262 rows x 21 columns]

# %%
cols = ('SNP_01', 'SNP_02', 'SNP_03', 'SNP_04', 'SNP_05', 'SNP_06',
       'SNP_07', 'SNP_08', 'SNP_09', 'SNP_10', 'SNP_11', 'SNP_12', 'SNP_13',
       'SNP_14', 'SNP_15')

# %%
for c in cols:
    lb = LabelEncoder() 
    lb.fit(list(test[c].values)) 
    test[c] = lb.transform(list(test[c].values))

# %%
test
# Out:
#            id  father  mother  gender  trait  SNP_01  SNP_02  SNP_03  SNP_04  \
# 0    TEST_000       0       0       0      1       1       2       0       1
# 1    TEST_001       0       0       0      2       2       1       2       2
# 2    TEST_002       0       0       0      2       2       1       0       0
# 3    TEST_003       0       0       0      2       2       1       1       0
# 4    TEST_004       0       0       0      1       0       2       0       2
# ..        ...     ...     ...     ...    ...     ...     ...     ...     ...
# 170  TEST_170       0       0       0      2       1       2       2       0
# 171  TEST_171       0       0       0      2       2       0       0       0
# 172  TEST_172       0       0       0      2       2       0       0       0
# 173  TEST_173       0       0       0      2       1       2       1       1
# 174  TEST_174       0       0       0      2       2       2       2       1
#
#      SNP_05  SNP_06  SNP_07  SNP_08  SNP_09  SNP_10  SNP_11  SNP_12  SNP_13  \
# 0         0       1       2       1       1       1       1       1       2
# 1         2       0       0       0       0       2       1       0       0
# 2         1       1       0       0       0       1       0       1       2
# 3         2       0       0       0       0       2       0       1       1
# 4         0       2       2       0       2       1       2       1       2
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 170       1       1       0       2       0       2       2       0       0
# 171       1       1       0       0       0       1       0       0       1
# 172       1       1       0       0       0       2       1       0       1
# 173       2       2       0       1       0       2       1       0       0
# 174       1       0       1       2       0       2       2       0       0
#
#      SNP_14  SNP_15
# 0         1       1
# 1         0       0
# 2         0       2
# 3         0       0
# 4         0       2
# ..      ...     ...
# 170       0       1
# 171       0       1
# 172       0       2
# 173       0       0
# 174       0       0
#
# [175 rows x 20 columns]

# %%
train = train.drop(['id','father', 'mother', 'gender'], axis=1)
test = test.drop(['id','father', 'mother', 'gender'], axis=1)
combine = [train, test]

# %% [markdown]
# ## Modeling

# %%
x_train = train.loc[:, 'trait':'SNP_15']
y_train = train['class']
x_test  = test.loc[:, 'trait':'SNP_15']

# %% [markdown]
# #### Logistic Regression - 1등
# - 제출 : 0.9814285714

# %%
## Logistic Regression
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(random_state=0) # model define
model.fit(x_train, y_train) # model fitting

y_pred = model.predict(x_train) # inference

# accuracy
lr_score = model.score(x_train, y_train)
lr_score
# Out:
# 0.9694656488549618

# %%
## Logistic Regression
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(random_state=0) # model define
model.fit(x_train, y_train) # model fitting

y_pred = model.predict(test) # inference
y_pred
# Out:
# array([0, 1, 2, 2, 0, 1, 2, 1, 0, 0, 2, 1, 2, 0, 1, 1, 0, 1, 1, 2, 1, 1,
#        1, 0, 1, 1, 1, 0, 0, 1, 0, 0, 1, 2, 0, 1, 2, 1, 1, 2, 0, 1, 2, 1,
#        1, 1, 1, 2, 1, 2, 0, 1, 0, 1, 1, 1, 2, 0, 1, 2, 0, 1, 2, 2, 2, 0,
#        1, 0, 0, 1, 1, 1, 0, 0, 2, 1, 2, 1, 1, 1, 2, 1, 0, 1, 1, 1, 1, 1,
#        2, 0, 1, 1, 2, 1, 1, 2, 0, 1, 0, 2, 0, 1, 1, 2, 0, 0, 2, 1, 0, 1,
#        2, 1, 1, 1, 1, 0, 0, 2, 1, 2, 0, 1, 1, 2, 2, 1, 1, 1, 0, 1, 0, 0,
#        1, 1, 1, 2, 0, 0, 1, 0, 0, 0, 2, 1, 1, 1, 0, 1, 2, 0, 0, 1, 0, 1,
#        1, 0, 0, 1, 2, 0, 1, 2, 2, 1, 0, 0, 2, 1, 1, 0, 1, 2, 2, 1, 1])

# %% [markdown]
# #### Gaussian Naive Bayes
# - 제출 : 0.8854854855

# %%
## Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB

model = GaussianNB() # model define
model.fit(x_train, y_train) # model fitting

y_pred = model.predict(x_train) # inference

# accuracy
nb_score = model.score(x_train, y_train)
nb_score
# Out:
# 0.8893129770992366

# %%
## Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB

model = GaussianNB() # model define
model.fit(x_train, y_train) # model fitting

y_pred = model.predict(x_test) # inference

# %% [markdown]
# ### KNN
# - 제출 : 0.9433551198

# %%
## K-nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=3) # define
model.fit(x_train, y_train) # fitting

y_pred = model.predict(x_train) # inference

# accuracy
knn_score = model.score(x_train, y_train)
knn_score
# Out:
# 0.9694656488549618

# %%
## K-nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=3) # define
model.fit(x_train, y_train) # fitting

y_pred = model.predict(x_test) # inference

# %% [markdown]
# ### Decision Tree
# - 미제출

# %%
## Decision Tree
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion='entropy', random_state=0, max_depth=3)
model.fit(x_train, y_train)

# inference
y_pred = model.predict(x_train)

# accuracy
dt_score = model.score(x_train, y_train)
dt_score
# Out:
# 0.8473282442748091

# %%
## Decision Tree
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion='entropy', random_state=0, max_depth=3)
model.fit(x_train, y_train)

# inference
y_pred = model.predict(x_test)

# %% [markdown]
# ### RandomForest
# - 미제출

# %%
## Random Forest
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=10, max_depth=3) # define
model.fit(x_train, y_train) # fitting

y_pred = model.predict(x_train)

# accuracy
rf_score = model.score(x_train, y_train)
rf_score
# Out:
# 0.9312977099236641

# %%
## Random Forest
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=10, max_depth=3) # define
model.fit(x_train, y_train) # fitting

y_pred = model.predict(x_test)

# %% [markdown]
# ### Support Vector Machine
# - 미제추ㄹ

# %%
## Support Vector Machine
from sklearn.svm import SVC

model = SVC(kernel='rbf', gamma='auto') # define
model.fit(x_train, y_train) # fitting

y_pred = model.predict(x_train)

# accuracy
svm_score = model.score(x_train, y_train)
svm_score
# Out:
# 0.9770992366412213

# %%
## Support Vector Machine
from sklearn.svm import SVC

model = SVC(kernel='rbf', gamma='auto') # define
model.fit(x_train, y_train) # fitting

y_pred = model.predict(x_test)

# %% [markdown]
# ### Gradient Boosting
# - 미제출

# %%
## Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier

model = GradientBoostingClassifier(n_estimators=100)
model.fit(x_train, y_train)

y_pred = model.predict(x_train)

# accuracy
gb_score = model.score(x_train, y_train)
gb_score
# Out:
# 1.0

# %%
## Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier

model = GradientBoostingClassifier(n_estimators=100)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %% [markdown]
# ### MLP
# - 미제출

# %%
## MLP by scikit-learn
from sklearn.neural_network import MLPClassifier

model = MLPClassifier(max_iter=1000)
model.fit(x_train, y_train)

y_pred = model.predict(x_train)

# accuracy
mlp_score = model.score(x_train, y_train)
mlp_score
# Out:
# 1.0

# %%
## MLP by scikit-learn
from sklearn.neural_network import MLPClassifier

model = MLPClassifier(max_iter=1000)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %% [markdown]
# ### XGBoost
# - 미제출

# %%
## XGBoost
# (참고) XGBoost 개념 정리 https://webnautes.tistory.com/1643
from xgboost import XGBClassifier, plot_importance

model = XGBClassifier(n_estimators=400)
model.fit(x_train, y_train)

y_pred = model.predict(x_train)

# acuracy
xgb_score = model.score(x_train, y_train)
xgb_score
# Out:
# 1.0

# %%
## XGBoost
# (참고) XGBoost 개념 정리 https://webnautes.tistory.com/1643
from xgboost import XGBClassifier, plot_importance

model = XGBClassifier(n_estimators=400)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %% [markdown]
# #### LGBM
# - 미제출

# %%
## LGBM (LightGBM)
from lightgbm import LGBMClassifier

model = LGBMClassifier(n_estimators=400)
model.fit(x_train, y_train)

y_pred = model.predict(x_train)

# accuracy
lgbm_score = model.score(x_train, y_train)
lgbm_score
# Out:
# 1.0

# %%
## LGBM (LightGBM)
from lightgbm import LGBMClassifier

model = LGBMClassifier(n_estimators=400)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %%
models = pd.DataFrame(
    data = [
        ['Logistic Regression', lr_score],
        ['Gaussian Naive Bayes', nb_score],
        ['K-nearest Neighbors', knn_score],
        ['Decision Tree', dt_score],
        ['Random Forest', rf_score],
        ['Support Vector Machine', svm_score],
        ['Gradient Boosting', gb_score],
        ['MLP', mlp_score],
        ['XGBoost', xgb_score],
        ['LightGBM', lgbm_score]
    ],
    columns = ['Model', 'Score']
)

models.set_index('Model', inplace=True)
models.sort_values('Score', ascending=False)
# Out:
#                            Score
# Model
# Gradient Boosting       1.000000
# MLP                     1.000000
# XGBoost                 1.000000
# LightGBM                1.000000
# Support Vector Machine  0.977099
# Logistic Regression     0.969466
# K-nearest Neighbors     0.969466
# Random Forest           0.931298
# Gaussian Naive Bayes    0.889313
# Decision Tree           0.847328

# %% [markdown]
# #### AutoML

# %% [markdown]
# - x_train = train.loc[:, 'trait':'SNP_15']
# - y_train = train['class']
# - x_test  = test.loc[:, 'trait':'SNP_15']

# %%
import os

from supervised.automl import AutoML

# %%
automl = AutoML(mode="Compete", eval_metric='accuracy')

# %%
automl.fit(x_train, y_train)
# Out:
# AutoML directory: AutoML_2
# The task is multiclass_classification with evaluation metric accuracy
# AutoML will use algorithms: ['Decision Tree', 'Linear', 'Random Forest', 'Extra Trees', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network', 'Nearest Neighbors']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree accuracy 0.740741 trained in 0.45 seconds
# Adjust validation. Remove: 1_DecisionTree
# *** Disable stacking for small dataset (nrows < 500)
# Validation strategy: 10-fold CV Shuffle,Stratify
# * Step simple_algorithms will try to check up to 4 models
# 1_DecisionTree accuracy 0.862595 trained in 2.82 seconds
# 2_DecisionTree accuracy 0.877863 trained in 2.52 seconds
# 3_DecisionTree accuracy 0.877863 trained in 3.17 seconds
# 4_Linear accuracy 0.954198 trained in 17.25 seconds
# * Step default_algorithms will try to check up to 7 models
# 5_Default_LightGBM accuracy 0.954198 trained in 7.06 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 6_Default_Xgboost accuracy 0.965649 trained in 7.87 seconds
# 7_Default_CatBoost accuracy 0.973282 trained in 4.48 seconds
# 8_Default_NeuralNetwork accuracy 0.919847 trained in 7.9 seconds
# 9_Default_RandomForest accuracy 0.954198 trained in 13.63 seconds
# 10_Default_ExtraTrees accuracy 0.958015 trained in 8.95 seconds
# 11_Default_NearestNeighbors accuracy 0.935115 trained in 3.85 seconds
# * Step not_so_random will try to check up to 61 models
# 21_LightGBM accuracy 0.954198 trained in 5.16 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 12_Xgboost accuracy 0.954198 trained in 8.52 seconds
# 30_CatBoost accuracy 0.973282 trained in 5.69 seconds
# 39_RandomForest accuracy 0.965649 trained in 10.34 seconds
# 48_ExtraTrees accuracy 0.942748 trained in 9.13 seconds
# 57_NeuralNetwork accuracy 0.946565 trained in 6.41 seconds
# 66_NearestNeighbors accuracy 0.938931 trained in 4.99 seconds
# 22_LightGBM accuracy 0.958015 trained in 6.3 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 13_Xgboost accuracy 0.958015 trained in 9.76 seconds
# 31_CatBoost accuracy 0.969466 trained in 6.35 seconds
# 40_RandomForest accuracy 0.954198 trained in 9.83 seconds
# 49_ExtraTrees accuracy 0.965649 trained in 10.03 seconds
# 58_NeuralNetwork accuracy 0.916031 trained in 7.57 seconds
# 67_NearestNeighbors accuracy 0.938931 trained in 5.83 seconds
# 23_LightGBM accuracy 0.958015 trained in 6.92 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 14_Xgboost accuracy 0.942748 trained in 9.71 seconds
# 32_CatBoost accuracy 0.950382 trained in 7.19 seconds
# 41_RandomForest accuracy 0.938931 trained in 10.5 seconds
# 50_ExtraTrees accuracy 0.954198 trained in 10.26 seconds
# 59_NeuralNetwork accuracy 0.916031 trained in 8.72 seconds
# 68_NearestNeighbors accuracy 0.938931 trained in 7.93 seconds
# 24_LightGBM accuracy 0.950382 trained in 8.38 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 15_Xgboost accuracy 0.435115 trained in 9.55 seconds
# 33_CatBoost accuracy 0.965649 trained in 8.02 seconds
# 42_RandomForest accuracy 0.961832 trained in 11.58 seconds
# 51_ExtraTrees accuracy 0.973282 trained in 10.92 seconds
# 60_NeuralNetwork accuracy 0.916031 trained in 11.27 seconds
# 69_NearestNeighbors accuracy 0.938931 trained in 12.21 seconds
# 25_LightGBM accuracy 0.965649 trained in 15.52 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 16_Xgboost accuracy 0.435115 trained in 11.25 seconds
# 34_CatBoost accuracy 0.961832 trained in 9.22 seconds
# 43_RandomForest accuracy 0.927481 trained in 21.09 seconds
# 52_ExtraTrees accuracy 0.946565 trained in 18.58 seconds
# 61_NeuralNetwork accuracy 0.931298 trained in 16.7 seconds
# 70_NearestNeighbors accuracy 0.912214 trained in 14.3 seconds
# 26_LightGBM accuracy 0.961832 trained in 16.27 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 17_Xgboost accuracy 0.931298 trained in 12.94 seconds
# 35_CatBoost accuracy 0.969466 trained in 9.84 seconds
# 44_RandomForest accuracy 0.938931 trained in 14.26 seconds
# 53_ExtraTrees accuracy 0.938931 trained in 13.12 seconds
# 62_NeuralNetwork accuracy 0.946565 trained in 13.16 seconds
# 71_NearestNeighbors accuracy 0.938931 trained in 15.42 seconds
# 27_LightGBM accuracy 0.958015 trained in 17.44 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 18_Xgboost accuracy 0.950382 trained in 15.36 seconds
# 36_CatBoost accuracy 0.961832 trained in 12.55 seconds
# 45_RandomForest accuracy 0.946565 trained in 23.86 seconds
# 54_ExtraTrees accuracy 0.961832 trained in 23.68 seconds
# 63_NeuralNetwork accuracy 0.946565 trained in 20.11 seconds
# 72_NearestNeighbors accuracy 0.912214 trained in 16.98 seconds
# 28_LightGBM accuracy 0.965649 trained in 20.8 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 19_Xgboost accuracy 0.622137 trained in 16.34 seconds
# 37_CatBoost accuracy 0.973282 trained in 13.11 seconds
# 46_RandomForest accuracy 0.950382 trained in 17.68 seconds
# 55_ExtraTrees accuracy 0.961832 trained in 24.77 seconds
# 64_NeuralNetwork accuracy 0.946565 trained in 18.75 seconds
# 29_LightGBM accuracy 0.950382 trained in 19.0 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 20_Xgboost accuracy 0.958015 trained in 27.28 seconds
# 38_CatBoost accuracy 0.961832 trained in 20.77 seconds
# 47_RandomForest accuracy 0.938931 trained in 28.64 seconds
# 56_ExtraTrees accuracy 0.950382 trained in 27.58 seconds
# 65_NeuralNetwork accuracy 0.927481 trained in 14.78 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: SNP_07_diff_SNP_10
# Add Golden Feature: SNP_03_sum_trait
# Add Golden Feature: SNP_13_sum_SNP_07
# Add Golden Feature: trait_ratio_SNP_13
# Add Golden Feature: SNP_13_ratio_trait
# Add Golden Feature: trait_diff_SNP_13
# Add Golden Feature: SNP_07_ratio_trait
# Add Golden Feature: trait_ratio_SNP_07
# Add Golden Feature: trait_diff_SNP_07
# Add Golden Feature: SNP_01_diff_SNP_07
# Created 10 Golden Features in 20.03 seconds.
# 37_CatBoost_GoldenFeatures accuracy 0.973282 trained in 34.53 seconds
# 30_CatBoost_GoldenFeatures accuracy 0.961832 trained in 14.57 seconds
# 51_ExtraTrees_GoldenFeatures accuracy 0.935115 trained in 17.8 seconds
# * Step kmeans_features will try to check up to 3 models
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# 37_CatBoost_KMeansFeatures accuracy 0.954198 trained in 23.04 seconds
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# 30_CatBoost_KMeansFeatures accuracy 0.969466 trained in 22.77 seconds
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
# 51_ExtraTrees_KMeansFeatures accuracy 0.958015 trained in 24.17 seconds
# * Step insert_random_feature will try to check up to 1 model
# 7_Default_CatBoost_RandomFeature accuracy 0.973282 trained in 17.4 seconds
# Drop features ['SNP_11', 'random_feature']
# * Step features_selection will try to check up to 6 models
# 7_Default_CatBoost_SelectedFeatures accuracy 0.969466 trained in 22.27 seconds
# 51_ExtraTrees_SelectedFeatures accuracy 0.961832 trained in 27.96 seconds
# 25_LightGBM_SelectedFeatures accuracy 0.965649 trained in 23.85 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 6_Default_Xgboost_SelectedFeatures accuracy 0.961832 trained in 27.77 seconds
# 39_RandomForest_SelectedFeatures accuracy 0.973282 trained in 18.46 seconds
# 57_NeuralNetwork_SelectedFeatures accuracy 0.923664 trained in 16.75 seconds
# * Step hill_climbing_1 will try to check up to 29 models
# 73_ExtraTrees accuracy 0.980916 trained in 19.1 seconds
# 74_ExtraTrees accuracy 0.954198 trained in 19.68 seconds
# 75_CatBoost accuracy 0.977099 trained in 19.18 seconds
# 76_CatBoost accuracy 0.977099 trained in 22.68 seconds
# 77_RandomForest_SelectedFeatures accuracy 0.961832 trained in 33.68 seconds
# 78_CatBoost accuracy 0.980916 trained in 26.16 seconds
# 79_CatBoost accuracy 0.973282 trained in 26.39 seconds
# 80_CatBoost accuracy 0.965649 trained in 25.96 seconds
# 81_ExtraTrees accuracy 0.965649 trained in 25.81 seconds
# 82_ExtraTrees accuracy 0.954198 trained in 22.29 seconds
# 83_LightGBM accuracy 0.961832 trained in 24.65 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 84_Xgboost accuracy 0.958015 trained in 28.32 seconds
# 85_LightGBM accuracy 0.973282 trained in 28.3 seconds
# 86_LightGBM accuracy 0.965649 trained in 27.17 seconds
# 87_LightGBM_SelectedFeatures accuracy 0.973282 trained in 27.89 seconds
# 88_LightGBM_SelectedFeatures accuracy 0.958015 trained in 27.76 seconds
# 89_ExtraTrees accuracy 0.965649 trained in 31.97 seconds
# 90_RandomForest accuracy 0.946565 trained in 23.77 seconds
# 91_RandomForest accuracy 0.938931 trained in 22.31 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 92_Xgboost_SelectedFeatures accuracy 0.965649 trained in 21.11 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 93_Xgboost accuracy 0.961832 trained in 20.95 seconds
# 94_NeuralNetwork accuracy 0.912214 trained in 18.99 seconds
# 95_NeuralNetwork accuracy 0.935115 trained in 19.45 seconds
# 96_NeuralNetwork accuracy 0.942748 trained in 20.13 seconds
# 97_NeuralNetwork accuracy 0.90458 trained in 20.71 seconds
# 98_NeuralNetwork accuracy 0.935115 trained in 19.27 seconds
# 99_DecisionTree accuracy 0.89313 trained in 18.4 seconds
# 100_DecisionTree accuracy 0.89313 trained in 18.88 seconds
# 101_DecisionTree accuracy 0.847328 trained in 17.93 seconds
# * Step hill_climbing_2 will try to check up to 23 models
# 102_CatBoost accuracy 0.961832 trained in 19.97 seconds
# 103_ExtraTrees accuracy 0.977099 trained in 23.01 seconds
# 104_ExtraTrees accuracy 0.980916 trained in 27.78 seconds
# 105_CatBoost accuracy 0.969466 trained in 28.93 seconds
# 106_ExtraTrees accuracy 0.969466 trained in 36.62 seconds
# 107_ExtraTrees accuracy 0.969466 trained in 38.56 seconds
# 108_RandomForest_SelectedFeatures accuracy 0.954198 trained in 40.45 seconds
# 109_RandomForest_SelectedFeatures accuracy 0.973282 trained in 38.12 seconds
# 110_LightGBM accuracy 0.973282 trained in 27.13 seconds
# 111_LightGBM_SelectedFeatures accuracy 0.965649 trained in 21.56 seconds
# 112_LightGBM accuracy 0.969466 trained in 22.87 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 113_Xgboost_SelectedFeatures accuracy 0.973282 trained in 26.06 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 114_Xgboost_SelectedFeatures accuracy 0.965649 trained in 25.78 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 115_Xgboost accuracy 0.965649 trained in 25.26 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 116_Xgboost accuracy 0.958015 trained in 34.98 seconds
# 117_ExtraTrees accuracy 0.969466 trained in 35.34 seconds
# 118_RandomForest accuracy 0.958015 trained in 36.74 seconds
# 119_RandomForest accuracy 0.961832 trained in 39.52 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 120_Xgboost accuracy 0.965649 trained in 40.26 seconds
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
# 121_Xgboost accuracy 0.961832 trained in 32.29 seconds
# 122_RandomForest_SelectedFeatures accuracy 0.954198 trained in 27.75 seconds
# 123_RandomForest_SelectedFeatures accuracy 0.961832 trained in 26.57 seconds
# 124_NeuralNetwork accuracy 0.916031 trained in 23.28 seconds
# * Step boost_on_errors will try to check up to 1 model
# 78_CatBoost_BoostOnErrors accuracy 0.977099 trained in 30.94 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble accuracy 0.984733 trained in 38.37 seconds
# AutoML fit time: 3265.39 seconds
# AutoML best model: Ensemble
# AutoML(eval_metric='accuracy', mode='Compete')

# %%
y_pred = automl.predict(x_test)

# %%
y_pred
# Out:
# array([0, 1, 2, 1, 0, 2, 2, 1, 0, 0, 2, 1, 1, 0, 1, 1, 0, 1, 1, 2, 1, 1,
#        1, 0, 1, 1, 1, 0, 0, 1, 0, 0, 1, 2, 0, 1, 2, 1, 1, 2, 0, 1, 2, 1,
#        1, 1, 1, 2, 1, 2, 0, 1, 0, 1, 1, 1, 2, 0, 1, 2, 0, 1, 2, 2, 2, 0,
#        1, 0, 0, 1, 1, 1, 0, 0, 2, 1, 2, 1, 1, 1, 2, 1, 0, 1, 1, 1, 1, 1,
#        2, 0, 1, 1, 2, 1, 1, 2, 0, 1, 0, 2, 0, 1, 1, 1, 0, 0, 2, 1, 0, 1,
#        2, 1, 1, 1, 1, 0, 0, 2, 1, 1, 0, 1, 1, 2, 2, 1, 2, 1, 0, 1, 0, 0,
#        1, 1, 1, 2, 0, 0, 1, 0, 0, 0, 2, 1, 1, 1, 0, 1, 2, 0, 0, 1, 0, 1,
#        1, 0, 0, 1, 2, 0, 1, 2, 2, 1, 0, 0, 2, 1, 1, 0, 1, 2, 2, 1, 1])

# %% [markdown]
# ## Submission

# %%
# Submission
submission = pd.DataFrame({"class" : train['class'], "class":y_pred})

submission
# Out:
#      class
# 0        0
# 1        1
# 2        2
# 3        1
# 4        0
# ..     ...
# 170      1
# 171      2
# 172      2
# 173      1
# 174      1
#
# [175 rows x 1 columns]

# %%
submission['class'] = submission['class'].map({0:'A', 1:'B', 2:'C'})
submission
# Out:
#     class
# 0       A
# 1       B
# 2       C
# 3       B
# 4       A
# ..    ...
# 170     B
# 171     C
# 172     C
# 173     B
# 174     B
#
# [175 rows x 1 columns]

# %%
results = pd.concat([idtest,submission],axis=1)
results
# Out:
#            id class
# 0    TEST_000     A
# 1    TEST_001     B
# 2    TEST_002     C
# 3    TEST_003     B
# 4    TEST_004     A
# ..        ...   ...
# 170  TEST_170     B
# 171  TEST_171     C
# 172  TEST_172     C
# 173  TEST_173     B
# 174  TEST_174     B
#
# [175 rows x 2 columns]

# %%
results.to_csv("AutoML_submission.csv", index = False)
